# %%
# !pip install tensorflow

# %%
# !pip install opencv-python

# %%
# !python --version
# !pip --version
# Out:
# Python 3.12.4
# pip 24.0 from C:\Users\manis\anaconda3\Lib\site-packages\pip (python 3.12)

# %%
# !pip install --upgrade pip
# Out:
# ...
#   Using cached pip-24.2-py3-none-any.whl.metadata (3.6 kB)
# Using cached pip-24.2-py3-none-any.whl (1.8 MB)
# ERROR: To modify pip, please run the following command:
# C:\Users\manis\anaconda3\python.exe -m pip install --upgrade pip

# %%
# !pip install flask

# %%
# !pip install keras

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import zipfile
import os

# Path to your zip file and extraction folder
zip_path = 'C:\\Users\\manis\\OneDrive\\Desktop\\Major Project\\Dataset.zip'
extract_path = 'C:\\Users\\manis\\OneDrive\\Desktop\\Major Project'

# Extract the dataset
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extracted successfully!")
# Out:
# Dataset extracted successfully!

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Set up the ImageDataGenerator with validation split
datagen = ImageDataGenerator(
    rescale=1./255,       # Normalize pixel values
    shear_range=0.2,      # Shear transformation for augmentation
    zoom_range=0.2,       # Randomly zoom in/out
    horizontal_flip=True, # Flip images horizontally
    validation_split=0.2  # Use 20% of the data for validation
)

# Define the path to your extracted dataset
dataset_path = r'C:\Users\manis\OneDrive\Desktop\Major Project\Dataset'

# Training data generator (80% training data)
train_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary',   # Change to 'categorical' for multi-class problems
    subset='training'      # Use 'training' subset
)

# Validation data generator (20% validation data)
validation_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary',
    subset='validation'    # Use 'validation' subset
)

print("Training and validation data loaded successfully!")
# Out:
# Found 8994 images belonging to 2 classes.
# Found 2248 images belonging to 2 classes.
# Training and validation data loaded successfully!

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Define a simple CNN model
model = Sequential()

# Convolutional layer with 32 filters, 3x3 kernel, and ReLU activation
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Another convolutional layer
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Another convolutional layer
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Flatten the output from the convolutional layers
model.add(Flatten())

# Fully connected layer with 128 neurons
model.add(Dense(128, activation='relu'))

# Dropout for regularization to prevent overfitting
model.add(Dropout(0.5))

# Output layer with sigmoid activation for binary classification
# Use 'softmax' if you're doing multi-class classification
model.add(Dense(1, activation='sigmoid'))

# Compile the model with optimizer, loss function, and metrics
model.compile(optimizer='adam', 
              loss='binary_crossentropy',  # Change to 'categorical_crossentropy' for multi-class
              metrics=['accuracy'])

# Print the model summary
model.summary()

# Train the model
history = model.fit(
    train_data,
    steps_per_epoch=train_data.samples // train_data.batch_size,  # Number of steps per epoch
    validation_data=validation_data,
    validation_steps=validation_data.samples // validation_data.batch_size,
    epochs=20  # Adjust the number of epochs as needed
)

# Save the model if you want to reuse it later
model.save('trained_model.h5')

print("Model training complete!")
# Out:
# C:\Users\manis\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)                    │ (None, 148, 148, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 74, 74, 32)          │               0 │
# ...

# %%
import matplotlib.pyplot as plt

# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#Testing the model
import numpy as np
import tensorflow as tf

# Load and preprocess the test image (make sure it's of the correct size)
test_image = tf.keras.preprocessing.image.load_img('Triangle.jpeg', target_size=(150, 150))
test_image = tf.keras.preprocessing.image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)  # Add batch dimension
test_image = test_image / 255.0  # Normalize the image

# Predict the class
predictions = model.predict(test_image)
pred = np.argmax(predictions)  # Get the index of the highest probability

# Define the class labels
index = ['circle', 'square', 'triangle']

# Map the predicted index to the corresponding shape label
result = str(index[pred])

# Output the predicted result
print(result)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# circle

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense

# Modify the model to flatten the input if necessary
model = Sequential([
    Flatten(input_shape=(64, 64, 3)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

# Now the model should accept (64, 64, 3) input

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

# Loading and preprocessing the image
img = image.load_img('101.png', target_size=(64, 64))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)  # Expanding dimensions to fit the model input

# Flattening the image if required by your model
x = x.reshape(1, -1)  # Reshape to (1, 64*64*3) which is (1, 12288)

# Predicting the class
pred = model.predict(x)
predicted_class = np.argmax(pred, axis=1)  # Getting the index of the highest probability

print(predicted_class)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 13
#      10 x = x.reshape(1, -1)  # Reshape to (1, 64*64*3) which is (1, 12288)
#      12 # Predicting the class
# ---> 13 pred = model.predict(x)
#      14 predicted_class = np.argmax(pred, axis=1)  # Getting the index of the highest probability
#      16 print(predicted_class)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# ...

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np

# Load the trained model
model = tf.keras.models.load_model('trained_model.h5')

# Define the index mapping for the classes (e.g., circle = 0, square = 1, triangle = 2)
index = ['circle', 'square', 'triangle']

# Load and preprocess the image
img = image.load_img('101.png', target_size=(150, 150))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)  # Add batch dimension (1, 150, 150, 3)
x /= 255.0  # Normalize the image (if needed)

# Predict the class
pred = model.predict(x)
predicted_class = np.argmax(pred, axis=1)  # Get the predicted class index

# Map the predicted index to the corresponding shape
result = str(index[predicted_class[0]])

# Print the result
print(result)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# circle
